# %% [markdown]
# # DATA ANALYSIS IN PREPARATION FOR KAGGLE COMPETITIONS
# ## Code 1 : sales-from-different-stores
# ## Different_stores_data_V2 :
# # Dataset from Kaggle.com

# %%
Project Title: 
#importing modules
import numpy as np
import pandas as pd
import matplotlib 

#Reading the data
newData = pd.read_csv('/kaggle/input/sales-from-different-stores/Different_stores_data_V2.csv')

# %%
#Assessing the Data at a glance: 50 records of the dataset 
newData.head(50)
# Out:
#    invoice_no      invoice_date customer_id  gender  age         category  \
# 0     I138884   10/30/2016 9:58     C241288  Female   28         Clothing
# 1     I317333   10/30/2016 9:58     C111565    Male   21            Shoes
# 2     I127801   10/30/2016 9:58     C266599    Male   20         Clothing
# 3     I173702   10/30/2016 9:58     C988172  Female   66            Shoes
# 4     I337046   10/30/2016 9:59     C189076  Female   53            Books
# 5     I227836   10/30/2016 9:59     C657758  Female   28         Clothing
# 6     I121056   10/30/2016 9:59     C151197  Female   49        Cosmetics
# 7     I293112   10/30/2016 9:59     C176086  Female   32         Clothing
# 8     I293455  10/30/2016 10:00     C159642    Male   69         Clothing
# 9     I326945  10/30/2016 10:00     C283361  Female   60         Clothing
# 10    I306368  10/30/2016 10:00     C240286  Female   36  Food & Beverage
# 11    I139207  10/30/2016 10:00     C191708  Female   29            Books
# ...

# %%
newData.tail()
# Out:
#       invoice_no      invoice_date customer_id  gender  age         category  \
# 99452    I219422  11/15/2016 12:43     C441542  Female   45         Souvenir
# 99453    I325143  11/15/2016 12:43     C569580    Male   27  Food & Beverage
# 99454    I824010  11/15/2016 12:44     C103292    Male   63  Food & Beverage
# 99455    I702964  11/15/2016 12:44     C800631    Male   56       Technology
# 99456    I232867  11/15/2016 12:44     C273973  Female   36         Souvenir
#
#        quantity  selling_price_per_unit  total_profit payment_method region  \
# 99452         5                   58.65       73.3125    Credit Card  South
# 99453         2                   10.46        6.2760           Cash  South
# 99454         2                   10.46        6.2760     Debit Card  South
# 99455         4                 4200.00     1680.0000           Cash  South
# 99456         3                   35.19       31.6710    Credit Card  South
#
#          state     shopping_mall
# ...

# %%
#Counting the records in the dataset
newData.count()
# Out:
# invoice_no                99457
# invoice_date              99457
# customer_id               99457
# gender                    99457
# age                       99457
# category                  99457
# quantity                  99457
# selling_price_per_unit    99457
# total_profit              99457
# payment_method            99457
# region                    99457
# state                     99457
# shopping_mall             99457
# dtype: int64

# %%
#Find the rows and the columns. (row., column)
newData.shape
# Out:
# (99457, 13)

# %%
#The structure of our data
newData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   invoice_no              99457 non-null  object
#  1   invoice_date            99457 non-null  object
#  2   customer_id             99457 non-null  object
#  3   gender                  99457 non-null  object
#  4   age                     99457 non-null  int64
#  5   category                99457 non-null  object
#  6   quantity                99457 non-null  int64
#  7   selling_price_per_unit  99457 non-null  float64
#  8   total_profit            99457 non-null  float64
#  9   payment_method          99457 non-null  object
#  10  region                  99457 non-null  object
#  11  state                   99457 non-null  object
#  12  shopping_mall           99457 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 9.9+ MB

# %%
#This can be done for all the title values
newData['shopping_mall']
# Out:
# 0                  Kanyon
# 1          Viaport Outlet
# 2               Metrocity
# 3            Metropol AVM
# 4                  Kanyon
#                ...
# 99452              Kanyon
# 99453      Viaport Outlet
# 99454           Metrocity
# 99455        Istinye Park
# 99456    Mall of Istanbul
# Name: shopping_mall, Length: 99457, dtype: object

# %%
#statistical overview of the data

newData.describe()
# Out:
#                 age      quantity  selling_price_per_unit  total_profit
# count  99457.000000  99457.000000            99457.000000  99457.000000
# mean      43.427089      3.004424              689.256321    230.751516
# std       14.990054      1.415237              941.184567    425.077533
# min       18.000000      1.000000                5.230000  -2625.000000
# 25%       30.000000      2.000000               45.450000     20.920000
# 50%       43.000000      3.000000              203.300000     94.687500
# 75%       56.000000      4.000000             1200.320000    300.080000
# max       69.000000     15.000000             5250.000000   7087.500000

# %%
#finding the mean age of the customers
newData['age'].mean()
# Out:
# 43.42708909377922

# %%
#finding the mean age of the customers
newData['age'].median()
# Out:
# 43.0

# %%
#box plot of the age range occurrance
newData['age'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %%
#density plot of the age range occurrance
newData['age'].plot(kind='density', figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %%
#density plot of the total profit
newData['total_profit'].plot(kind='density', figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %%
#STILL EDITING IT. TO REVERT LATER
histograph = newData['total_profit'].plot(kind='hist', figsize=(14,6))
histograph.set_ylabel('quantity')
histograph.set_xlabel('category')
# Out:
# Text(0.5, 0, 'category')

# %% [markdown]
# ## Categorical Analysis and Visualization
# We will analyze the region where most sales have been made

# %%
#Region Data Analysis
regionData = newData['region'].value_counts()
regionData
# Out:
# region
# West       31843
# East       28306
# Central    23099
# South      16209
# Name: count, dtype: int64

# %%
#Pie chart representation of the sales per region
regionData.plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %%
#statistics of the ages of the customers
countData = newData['age'].value_counts()
countData
# Out:
# age
# 37    2057
# 22    2051
# 64    2002
# 43    2000
# 51    1993
# 30    1981
# 24    1977
# 40    1960
# 48    1955
# 36    1954
# 38    1954
# 28    1953
# 27    1950
# 39    1947
# 21    1947
# 61    1945
# 52    1945
# 19    1936
# 56    1916
# 33    1913
# 46    1911
# 62    1909
# 44    1904
# 53    1903
# 67    1901
# 69    1901
# 23    1897
# 26    1896
# 68    1893
# 42    1892
# 41    1892
# 32    1891
# 63    1886
# 29    1885
# 49    1883
# 34    1883
# 47    1880
# 57    1879
# 66    1876
# 45    1876
# 58    1875
# 59    1874
# 60    1874
# 50    1873
# 31    1866
# 25    1863
# 65    1856
# 18    1844
# 20    1844
# 55    1843
# 35    1841
# 54    1830
# Name: count, dtype: int64

# %%
newData.head()
# Out:
#   invoice_no     invoice_date customer_id  gender  age  category  quantity  \
# 0    I138884  10/30/2016 9:58     C241288  Female   28  Clothing         5
# 1    I317333  10/30/2016 9:58     C111565    Male   21     Shoes         3
# 2    I127801  10/30/2016 9:58     C266599    Male   20  Clothing         1
# 3    I173702  10/30/2016 9:58     C988172  Female   66     Shoes         5
# 4    I337046  10/30/2016 9:59     C189076  Female   53     Books         4
#
#    selling_price_per_unit  total_profit payment_method region       state  \
# 0                 1500.40       375.100    Credit Card  South    Kentucky
# 1                 1800.51       540.153     Debit Card  South    Kentucky
# 2                  300.08         5.020           Cash   West  California
# 3                 3000.85       500.425    Credit Card  South     Florida
# 4                   60.60        60.600           Cash  South     Florida
#
#     shopping_mall
# 0          Kanyon
# 1  Viaport Outlet
# ...

# %%
#Finding which payment method was used mostly
pMethod = newData['payment_method'].value_counts()
pMethod
# Out:
# payment_method
# Cash           44447
# Credit Card    34931
# Debit Card     20079
# Name: count, dtype: int64

# %%
#The pie chart representation of the payment methods
pMethod.plot(kind='pie' , figsize=(6, 6))
# Out:
# <Axes: ylabel='count'>

# %%
#The product category according to customer purchase.
newData['category'].value_counts()
# Out:
# category
# Clothing           34487
# Cosmetics          15097
# Food & Beverage    14776
# Toys               10087
# Shoes              10034
# Souvenir            4999
# Technology          4996
# Books               4981
# Name: count, dtype: int64

# %%
#Pie chart diagram of the frequency of purchase of an item category
newData['category'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %%
pd.Dataframe({'NAMES':['chris', 'ann', tiphany]})
